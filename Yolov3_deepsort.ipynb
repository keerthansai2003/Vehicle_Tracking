# %% [markdown]
# Standard Imports

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import cv2
import numpy as np
import tensorflow as tf
from yolov3.utils import Load_Yolo_model, image_preprocess, postprocess_boxes, nms, draw_bbox, read_class_names
from yolov3.configs import *
import time
from deep_sort import nn_matching
from deep_sort.detection import Detection
from deep_sort.tracker import Tracker
from deep_sort import generate_detections as gdet

# %%
path_to_video   = "video3.mp4"

def Car_tracking(Yolo, path_to_video, output_path, input_size=400, show=False, CLASSES=YOLO_COCO_CLASSES, score_threshold=0.2, iou_threshold=0.4, rectangle_colors='', Track_only = []):
    
    max_distance = 0.6
    
    #initialize deep sort object
    model_filename = 'model_data/coco/mars-small128.pb'
    encoder = gdet.create_box_encoder(model_filename, batch_size=1)
    eval_metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_distance,None)
    tracker = Tracker(eval_metric)

    time1 = []
    time2 = []

    if path_to_video:
        vid = cv2.VideoCapture(path_to_video) # detect on video
    else:
        vid = cv2.VideoCapture(0) # detect from webcam

    # by default VideoCapture returns float instead of int
    w = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(vid.get(cv2.CAP_PROP_FPS))
    codec = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, codec, fps, (w, h)) # output_path must be .mp4

    NUM_CLASS = read_class_names(CLASSES)
    key_list = list(NUM_CLASS.keys()) 
    val_list = list(NUM_CLASS.values())
    while True:
        _, frame = vid.read()

        try: #converting each frame (image) of the video into RGB format
            original_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        except:
            break
        
        image_data = image_preprocess(np.copy(original_frame), [input_size, input_size]) #changing the image dimentions. 
        # image_data = image_data[np.newaxis, ...].astype(np.float32)
        image_data = np.float32(image_data[np.newaxis, ...])

        t1 = time.time()
        if YOLO_FRAMEWORK == "tf":
            pred_boundingbox = Yolo.predict(image_data)
        elif YOLO_FRAMEWORK == "trt":
            batched_input = tf.constant(image_data)
            result = Yolo(batched_input)
            pred_boundingbox = []
            for key, value in result.items():
                value = value.numpy()
                pred_boundingbox.append(value)
        
        t2 = time.time()
        
        pred_boundingbox = [tf.reshape(x, (-1, tf.shape(x)[-1])) for x in pred_boundingbox]
        pred_boundingbox = tf.concat(pred_boundingbox, axis=0)

        boundingboxes = postprocess_boxes(pred_boundingbox, original_frame, input_size, score_threshold)
        boundingboxes = nms(boundingboxes, iou_threshold, method='nms')

        # extract bboxes to boxes (x, y, width, height), scores and names
        # boxes, scores, names = [], [], []
        boxes = []
        scores = []
        names = []

        for boundingbox in boundingboxes:
            if len(Track_only) !=0 and NUM_CLASS[int(boundingbox[5])] in Track_only or len(Track_only) == 0:
                boxes.append([boundingbox[0].astype(int), boundingbox[1].astype(int), boundingbox[2].astype(int)-boundingbox[0].astype(int), boundingbox[3].astype(int)-boundingbox[1].astype(int)])
                scores.append(boundingbox[4])
                names.append(NUM_CLASS[int(boundingbox[5])])

        #Obtaining all the detections for a frame of he video
        boxes = np.array(boxes) 
        names = np.array(names)
        scores = np.array(scores)
        features = np.array(encoder(original_frame, boxes))
        detections = [Detection(boundingbox, score, class_name, feature) for boundingbox, score, class_name, feature in zip(boxes, scores, names, features)]

        # Obtaining track information after passing the detections to the deepsort object
        tracker.predict()
        tracker.update(detections)

        # Obtain info from the tracks
        tracked_boundingboxes = []
        for track in tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 5:
                continue 
            boundingbox = track.to_tlbr() # Get the corrected/predicted bounding box
            class_name = track.get_class() #Get the class name of particular object
            tracking_id = track.track_id # Get the ID for the particular track
            index = key_list[val_list.index(class_name)] # Get predicted object index by object name
            tracked_boundingboxes.append(boundingbox.tolist() + [tracking_id, index]) # Structure data, that we could use it with our draw_bbox function

        # drawing the detections on a frame
        image = draw_bbox(original_frame, tracked_boundingboxes, CLASSES=CLASSES, tracking=True)

        t3 = time.time()
        time1.append(t2-t1)
        time2.append(t3-t1)
        
        time1 = time1[-20:]
        time2 = time2[-20:]

        ms = sum(time1)/len(time1)*1000
        fps = 1000 / ms
        fps2 = 1000 / (sum(time2)/len(time2)*1000)
        
        image = cv2.putText(image, "Time: {:.1f} FPS".format(fps), (0, 30), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 255, 0), 2)


        print("Time: {:.2f}ms, Detection FPS: {:.1f}, total FPS: {:.1f}".format(ms, fps, fps2))
        if output_path != '': out.write(image)
        if show:
            cv2.imshow('output', image)
            
            if cv2.waitKey(25) & 0xFF == ord("q"):
                cv2.destroyAllWindows()
                break
            
    cv2.destroyAllWindows()


yolo_v3 = Load_Yolo_model()
Car_tracking(yolo_v3, path_to_video, "output.mp4", input_size=YOLO_INPUT_SIZE, show=False, iou_threshold=0.1, rectangle_colors=(0,0, 255), Track_only = ["car"])
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 1/1 [==============================] - 8s 8s/step
# Time: 8249.89ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 2s 2s/step
# Time: 5469.31ms, Detection FPS: 0.2, total FPS: 0.1
# 1/1 [==============================] - 1s 1s/step
# Time: 4304.00ms, Detection FPS: 0.2, total FPS: 0.2
# 1/1 [==============================] - 1s 968ms/step
# Time: 3522.58ms, Detection FPS: 0.3, total FPS: 0.2
# 1/1 [==============================] - 1s 810ms/step
# Time: 2996.95ms, Detection FPS: 0.3, total FPS: 0.2
# 1/1 [==============================] - 1s 926ms/step
# Time: 2663.25ms, Detection FPS: 0.4, total FPS: 0.3
# 1/1 [==============================] - 1s 678ms/step
# Time: 2397.12ms, Detection FPS: 0.4, total FPS: 0.3
# 1/1 [==============================] - 1s 751ms/step
# Time: 2197.15ms, Detection FPS: 0.5, total FPS: 0.3
# 1/1 [==============================] - 1s 730ms/step
# Time: 2041.15ms, Detection FPS: 0.5, total FPS: 0.4
# 1/1 [==============================] - 1s 696ms/step
# Time: 1912.94ms, Detection FPS: 0.5, total FPS: 0.4
# 1/1 [==============================] - 1s 724ms/step
# Time: 1810.58ms, Detection FPS: 0.6, total FPS: 0.4
# 1/1 [==============================] - 1s 699ms/step
# Time: 1723.13ms, Detection FPS: 0.6, total FPS: 0.4
# 1/1 [==============================] - 1s 679ms/step
# Time: 1648.45ms, Detection FPS: 0.6, total FPS: 0.5
# 1/1 [==============================] - 1s 677ms/step
# Time: 1582.88ms, Detection FPS: 0.6, total FPS: 0.5
# 1/1 [==============================] - 1s 672ms/step
# Time: 1528.03ms, Detection FPS: 0.7, total FPS: 0.5
# 1/1 [==============================] - 1s 679ms/step
# Time: 1478.97ms, Detection FPS: 0.7, total FPS: 0.5
# 1/1 [==============================] - 1s 646ms/step
# Time: 1433.39ms, Detection FPS: 0.7, total FPS: 0.5
# 1/1 [==============================] - 1s 660ms/step
# Time: 1394.03ms, Detection FPS: 0.7, total FPS: 0.5
# 1/1 [==============================] - 1s 664ms/step
# Time: 1358.47ms, Detection FPS: 0.7, total FPS: 0.6
# 1/1 [==============================] - 1s 711ms/step
# Time: 1328.77ms, Detection FPS: 0.8, total FPS: 0.6
# 1/1 [==============================] - 1s 708ms/step
# Time: 954.57ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 737ms/step
# Time: 860.42ms, Detection FPS: 1.2, total FPS: 0.9
# 1/1 [==============================] - 1s 687ms/step
# Time: 799.00ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 878ms/step
# Time: 786.36ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 659ms/step
# Time: 777.37ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 639ms/step
# Time: 761.72ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 647ms/step
# Time: 757.47ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 658ms/step
# Time: 754.38ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 633ms/step
# Time: 749.17ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 676ms/step
# Time: 748.98ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 685ms/step
# Time: 748.41ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 651ms/step
# Time: 745.57ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 671ms/step
# Time: 744.73ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 666ms/step
# Time: 744.88ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 705ms/step
# Time: 745.15ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 741ms/step
# Time: 748.17ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 719ms/step
# Time: 751.81ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 663ms/step
# Time: 751.21ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 705ms/step
# Time: 753.22ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 736ms/step
# Time: 756.48ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 671ms/step
# Time: 754.24ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 648ms/step
# Time: 748.60ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 764ms/step
# Time: 752.46ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 731ms/step
# Time: 745.53ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 1s/step
# Time: 770.14ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 1s/step
# Time: 808.29ms, Detection FPS: 1.2, total FPS: 0.9
# 1/1 [==============================] - 2s 2s/step
# Time: 930.81ms, Detection FPS: 1.1, total FPS: 0.8
# 1/1 [==============================] - 2s 2s/step
# Time: 1072.91ms, Detection FPS: 0.9, total FPS: 0.7
# 1/1 [==============================] - 1s 1s/step
# Time: 1124.89ms, Detection FPS: 0.9, total FPS: 0.7
# 1/1 [==============================] - 2s 2s/step
# Time: 1201.25ms, Detection FPS: 0.8, total FPS: 0.6
# 1/1 [==============================] - 3s 3s/step
# Time: 1354.99ms, Detection FPS: 0.7, total FPS: 0.6
# 1/1 [==============================] - 2s 2s/step
# Time: 1538.75ms, Detection FPS: 0.6, total FPS: 0.5
# 1/1 [==============================] - 4s 4s/step
# Time: 1730.55ms, Detection FPS: 0.6, total FPS: 0.5
# 1/1 [==============================] - 2s 2s/step
# Time: 1833.35ms, Detection FPS: 0.5, total FPS: 0.4
# 1/1 [==============================] - 2s 2s/step
# Time: 2035.82ms, Detection FPS: 0.5, total FPS: 0.4
# 1/1 [==============================] - 2s 2s/step
# Time: 2120.43ms, Detection FPS: 0.5, total FPS: 0.4
# 1/1 [==============================] - 2s 2s/step
# Time: 2256.22ms, Detection FPS: 0.4, total FPS: 0.4
# 1/1 [==============================] - 98s 98s/step
# Time: 7244.90ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 17s 17s/step
# Time: 8256.63ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 2s 2s/step
# Time: 8360.85ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 2s 2s/step
# Time: 8431.60ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 2s 2s/step
# Time: 8487.75ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 912ms/step
# Time: 8495.47ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 978ms/step
# Time: 8508.36ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 1s/step
# Time: 8515.73ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 904ms/step
# Time: 8513.37ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 904ms/step
# Time: 8403.55ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 917ms/step
# Time: 8274.42ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 881ms/step
# Time: 8235.52ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 951ms/step
# Time: 8172.54ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 941ms/step
# Time: 8031.22ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 701ms/step
# Time: 7850.73ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 677ms/step
# Time: 7659.78ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 699ms/step
# Time: 7558.41ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 713ms/step
# Time: 7356.12ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 664ms/step
# Time: 7267.27ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 668ms/step
# Time: 7128.45ms, Detection FPS: 0.1, total FPS: 0.1
# 1/1 [==============================] - 1s 673ms/step
# Time: 2140.69ms, Detection FPS: 0.5, total FPS: 0.4
# 1/1 [==============================] - 1s 655ms/step
# Time: 1126.02ms, Detection FPS: 0.9, total FPS: 0.7
# 1/1 [==============================] - 1s 662ms/step
# Time: 1015.84ms, Detection FPS: 1.0, total FPS: 0.7
# 1/1 [==============================] - 1s 765ms/step
# Time: 949.67ms, Detection FPS: 1.1, total FPS: 0.8
# 1/1 [==============================] - 1s 661ms/step
# Time: 894.60ms, Detection FPS: 1.1, total FPS: 0.8
# 1/1 [==============================] - 1s 653ms/step
# Time: 882.35ms, Detection FPS: 1.1, total FPS: 0.9
# 1/1 [==============================] - 1s 675ms/step
# Time: 866.53ms, Detection FPS: 1.2, total FPS: 0.9
# 1/1 [==============================] - 1s 683ms/step
# Time: 835.57ms, Detection FPS: 1.2, total FPS: 0.9
# 1/1 [==============================] - 1s 667ms/step
# Time: 801.36ms, Detection FPS: 1.2, total FPS: 0.9
# 1/1 [==============================] - 1s 633ms/step
# Time: 787.59ms, Detection FPS: 1.3, total FPS: 0.9
# 1/1 [==============================] - 1s 662ms/step
# Time: 773.15ms, Detection FPS: 1.3, total FPS: 0.9
# 1/1 [==============================] - 1s 681ms/step
# Time: 762.24ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 668ms/step
# Time: 747.98ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 692ms/step
# Time: 734.46ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 657ms/step
# Time: 731.50ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 640ms/step
# Time: 729.28ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 654ms/step
# Time: 727.20ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 762ms/step
# Time: 729.58ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 675ms/step
# Time: 729.83ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 679ms/step
# Time: 730.32ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 667ms/step
# Time: 729.40ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 654ms/step
# Time: 730.35ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 658ms/step
# Time: 730.45ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 706ms/step
# Time: 728.06ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 643ms/step
# Time: 727.48ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 739ms/step
# Time: 732.02ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 685ms/step
# Time: 732.57ms, Detection FPS: 1.4, total FPS: 1.0
# 1/1 [==============================] - 1s 1s/step
# Time: 762.34ms, Detection FPS: 1.3, total FPS: 1.0
# 1/1 [==============================] - 1s 1s/step
# Time: 794.87ms, Detection FPS: 1.3, total FPS: 0.9
# 1/1 [==============================] - 1s 987ms/step
# Time: 827.67ms, Detection FPS: 1.2, total FPS: 0.9
# 1/1 [==============================] - 1s 950ms/step
# Time: 844.58ms, Detection FPS: 1.2, total FPS: 0.9
# 1/1 [==============================] - 1s 1s/step
# Time: 867.30ms, Detection FPS: 1.2, total FPS: 0.9
# 1/1 [==============================] - 1s 904ms/step
# Time: 879.34ms, Detection FPS: 1.1, total FPS: 0.9
# 1/1 [==============================] - 1s 997ms/step
# Time: 894.72ms, Detection FPS: 1.1, total FPS: 0.8
# 1/1 [==============================] - 1s 905ms/step
# Time: 907.80ms, Detection FPS: 1.1, total FPS: 0.8
# 1/1 [==============================] - 1s 1s/step
# Time: 940.13ms, Detection FPS: 1.1, total FPS: 0.8
# 1/1 [==============================] - 1s 881ms/step
# Time: 951.52ms, Detection FPS: 1.1, total FPS: 0.8
# 1/1 [==============================] - 1s 831ms/step
# Time: 955.16ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 827ms/step
# Time: 963.50ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 830ms/step
# Time: 994.81ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 914ms/step
# Time: 1008.32ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 839ms/step
# Time: 1017.81ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 882ms/step
# Time: 1029.62ms, Detection FPS: 1.0, total FPS: 0.7
# 1/1 [==============================] - 1s 853ms/step
# Time: 1037.54ms, Detection FPS: 1.0, total FPS: 0.7
# 1/1 [==============================] - 1s 861ms/step
# Time: 1048.26ms, Detection FPS: 1.0, total FPS: 0.7
# 1/1 [==============================] - 1s 880ms/step
# Time: 1054.07ms, Detection FPS: 0.9, total FPS: 0.7
# 1/1 [==============================] - 1s 912ms/step
# Time: 1066.69ms, Detection FPS: 0.9, total FPS: 0.7
# 1/1 [==============================] - 1s 971ms/step
# Time: 1069.27ms, Detection FPS: 0.9, total FPS: 0.7
# 1/1 [==============================] - 1s 831ms/step
# Time: 1046.14ms, Detection FPS: 1.0, total FPS: 0.7
# 1/1 [==============================] - 1s 847ms/step
# Time: 1027.05ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 861ms/step
# Time: 1020.88ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 880ms/step
# Time: 1008.76ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 840ms/step
# Time: 1028.00ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 831ms/step
# Time: 1020.60ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 834ms/step
# Time: 1040.30ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 846ms/step
# Time: 1018.68ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 848ms/step
# Time: 1017.54ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 1s/step
# Time: 1050.13ms, Detection FPS: 1.0, total FPS: 0.8
# 1/1 [==============================] - 1s 866ms/step
# Time: 1054.55ms, Detection FPS: 0.9, total FPS: 0.8
